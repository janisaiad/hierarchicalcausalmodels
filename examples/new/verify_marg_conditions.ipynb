# %% [markdown]
# # Vérification `marginalization_Qc_eligible_parents`
#
# Compare l’ensemble éligible (règle papier + restriction aux successeurs `Q^…`) aux choix manuels de la galerie `COLLAPSED_DO_CALCULUS_CASES`. Exécuter la cellule suivante (répertoire de travail = `examples/new/`).

# %%
# %run verify_marg_conditions.py
